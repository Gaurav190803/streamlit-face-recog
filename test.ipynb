# %%
import pickle as pkl
with open("dataset/database.pkl","rb") as f:
    database = pkl.load(f)

# %%
database
# Out:
# {'36e553d4': {'id': '36e553d4',
#   'name': 'gaurav',
#   'phone': '1234',
#   'image': array([[[118, 136, 194],
#           [118, 136, 194],
#           [118, 136, 194],
#           ...,
#           [255, 250, 252],
#           [255, 250, 252],
#           [255, 250, 252]],
#
#          [[118, 136, 194],
#           [118, 136, 194],
#           [118, 136, 194],
#           ...,
#           [255, 250, 252],
#           [255, 250, 252],
#           [255, 250, 252]],
#
#          [[118, 136, 194],
#           [118, 136, 194],
#           [118, 136, 194],
#           ...,
#           [255, 250, 252],
#           [255, 250, 252],
#           [255, 250, 252]],
#
#          ...,
#
#          [[109,  77,  61],
#           [ 88,  56,  40],
#           [ 88,  56,  40],
#           ...,
#           [ 72,  66,  71],
#           [ 72,  66,  71],
#           [ 72,  66,  71]],
#
#          [[109,  77,  61],
#           [ 88,  56,  40],
#           [ 88,  56,  40],
#           ...,
# ...
